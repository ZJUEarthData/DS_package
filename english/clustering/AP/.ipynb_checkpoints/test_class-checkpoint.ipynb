# %%
from AP_class import *
import pandas as pd
from sklearn.cluster import AffinityPropagation
from sklearn.model_selection import GridSearchCV,ParameterGrid

# %%
    df = pd.read_excel('test4.xlsx')

    data = df.drop('TRUE VALUE', axis=1)
    labels = df['TRUE VALUE']

    # test unsupervised model
    t=AP()
    ap = AffinityPropagation(random_state=42)
    ap_dict = t.read_para()
    output = t.APGridsearch(ap, data, labels, ap_dict)

    # ap test result
    for i in range(len(output)):
        t.get_marks(output[i], data=data, labels=labels, name="output" + str(i))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-a68685b54d74> in <module>
#       7 t=AP()
#       8 ap = AffinityPropagation(random_state=42)
# ----> 9 ap_dict = t.read_para()
#      10 output = t.APGridsearch(ap, data, labels, ap_dict)
#      11
#
# TypeError: read_para() takes 0 positional arguments but 1 was given
