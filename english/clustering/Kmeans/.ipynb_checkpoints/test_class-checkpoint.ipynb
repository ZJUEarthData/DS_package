# %%
from kmeans_class import *
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.model_selection import GridSearchCV,ParameterGrid

# %%
df = pd.read_excel('test4.xlsx')
data = df.drop('TRUE VALUE', axis=1)
labels = df['TRUE VALUE']

# Test kmeans model
GeoKmeans = GeoKmeans()
kmeans=KMeans()
kmeans_dict = GeoKmeans.read_para()
output = GeoKmeans.KmeansGridsearch(kmeans,data,kmeans_dict)

# kmeans test results
for i in range(len(output)):
    GeoKmeans.get_marks(output[i], data=data, labels=labels, name="output" + str(i))
# Out:
# ****************************** output0 ******************************
# Model and parameters:  KMeans(n_clusters=3)
# Homogeneity Score         :  0.5549512618208781
# Completeness Score        :  0.8555973568749705
# V-Measure Score           :  0.6732342671709858
# Adjusted Rand Score       :  0.6800093729110801
# Adjusted Mutual Info Score:  0.6721202165706559
# Calinski Harabasz Score:    1113.8685257899092
# Silhouette Score          :  0.664093045850933
# ****************************** output1 ******************************
# Model and parameters:  KMeans(n_clusters=4)
# Homogeneity Score         :  0.7457399410842509
# Completeness Score        :  0.8448372457330804
# V-Measure Score           :  0.7922015769878176
# Adjusted Rand Score       :  0.8149667143643013
# Adjusted Mutual Info Score:  0.7912849716244518
# Calinski Harabasz Score:    1105.0422300885427
# Silhouette Score          :  0.6458696656931824
# ****************************** output2 ******************************
# Model and parameters:  KMeans(n_clusters=5)
# Homogeneity Score         :  0.7386945806216931
# Completeness Score        :  0.689225067088799
# V-Measure Score           :  0.7131029014180821
# Adjusted Rand Score       :  0.697755576113046
# Adjusted Mutual Info Score:  0.7115797134398348
# Calinski Harabasz Score:    1130.6232287800535
# Silhouette Score          :  0.6589950531796837
# ****************************** output3 ******************************
# Model and parameters:  KMeans(init='random', n_clusters=3)
# Homogeneity Score         :  0.5549512618208781
# Completeness Score        :  0.8555973568749705
# V-Measure Score           :  0.6732342671709858
# Adjusted Rand Score       :  0.6800093729110801
# Adjusted Mutual Info Score:  0.6721202165706559
# Calinski Harabasz Score:    1113.8685257899094
# Silhouette Score          :  0.664093045850933
# ****************************** output4 ******************************
# Model and parameters:  KMeans(init='random', n_clusters=4)
# Homogeneity Score         :  0.7457399410842511
# Completeness Score        :  0.8448372457330806
# V-Measure Score           :  0.7922015769878177
# Adjusted Rand Score       :  0.8149667143643013
# Adjusted Mutual Info Score:  0.791284971624452
# Calinski Harabasz Score:    1105.0422300885427
# Silhouette Score          :  0.6458696656931824
# ****************************** output5 ******************************
# Model and parameters:  KMeans(init='random', n_clusters=5)
# Homogeneity Score         :  0.7374283804166837
# Completeness Score        :  0.6875822641180962
# V-Measure Score           :  0.7116335269163933
# Adjusted Rand Score       :  0.6984178443876293
# Adjusted Mutual Info Score:  0.7101030817312814
# Calinski Harabasz Score:    1130.60631450395
# Silhouette Score          :  0.6590111551034573
